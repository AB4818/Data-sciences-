# %%
import pandas as pd

# %%
import numpy as np
from sklearn.feature_selection import SelectKBest
from numpy import set_printoptions
from sklearn.feature_selection import chi2
from pandas import read_csv

# %%
filename='/content/pima-indians-diabetes.data.csv'
names =['preg','plas','pres','skin','test','mass','pedi','ages','class']

# %%
dataframe=read_csv(filename,names=names)
array=dataframe.values 
dataframe.head()
# Out:
#    preg  plas  pres  skin  test  mass   pedi  ages  class
# 0     6   148    72    35     0  33.6  0.627    50      1
# 1     1    85    66    29     0  26.6  0.351    31      0
# 2     8   183    64     0     0  23.3  0.672    32      1
# 3     1    89    66    23    94  28.1  0.167    21      0
# 4     0   137    40    35   168  43.1  2.288    33      1

# %%
x =array[:,0:8]
y=array[:,8]

# %%
test=SelectKBest(score_func=chi2,k=5)
fit=test.fit(x,y)
set_printoptions(precision=4)
print(fit.scores_)
features=fit.transform(x)
# Out:
# [ 111.5197 1411.887    17.6054   53.108  2175.5653  127.6693    5.3927
#   181.3037]

# %%
names
# Out:
# ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'ages', 'class']

# %%
type(test)
# Out:
# sklearn.feature_selection._univariate_selection.SelectKBest

# %%
x=pd.DataFrame(fit.scores_).T

# %%
x
# Out:
#             0            1          2         3            4           5  \
# 0  111.519691  1411.887041  17.605373  53.10804  2175.565273  127.669343
#
#           6           7
# 0  5.392682  181.303689

# %%
x.columns=names[:8]

# %%
x
# Out:
#          preg         plas       pres      skin         test        mass  \
# 0  111.519691  1411.887041  17.605373  53.10804  2175.565273  127.669343
#
#        pedi        ages
# 0  5.392682  181.303689

# %% [markdown]
# # RFE

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest
from numpy import set_printoptions
from sklearn.feature_selection import chi2
from pandas import read_csv
from sklearn.linear_model import  LogisticRegression
from sklearn.feature_selection import RFE

# %%
ilename='/content/pima-indians-diabetes.data.csv'
names =['preg','plas','pres','skin','test','mass','pedi','ages','class']

# %%
dataframe=read_csv(filename,names=names)
array=dataframe.values 
dataframe.head()
x =array[:,0:8]
y=array[:,8]

# %%
model =LogisticRegression(max_iter=400)
ref=RFE(model)
fit=ref.fit(x,y)

# %%
fit.n_features_
# Out:
# 4

# %%
fit.support_
# Out:
# array([ True,  True, False, False, False,  True,  True, False])

# %%
names
# Out:
# ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'ages', 'class']

# %%
fit.ranking_
# Out:
# array([1, 1, 3, 5, 4, 1, 1, 2])

# %% [markdown]
# DECISION TREE FESTURE SELECTION

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest
from numpy import set_printoptions
from sklearn.feature_selection import chi2
from pandas import read_csv
from sklearn.linear_model import  LogisticRegression
from sklearn.feature_selection import RFE
from sklearn.tree import DecisionTreeClassifier

# %%
ilename='/content/pima-indians-diabetes.data.csv'
names =['preg','plas','pres','skin','test','mass','pedi','ages','class']

# %%
dataframe=read_csv(filename,names=names)
array=dataframe.values 
dataframe.head()
x =array[:,0:8]
y=array[:,8]

# %%
model=DecisionTreeClassifier()
model.fit(x,y)
print(model.feature_importances_)
# Out:
# [0.0578 0.3403 0.0784 0.0181 0.0307 0.218  0.1399 0.1168]

# %%
names
# Out:
# ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'ages', 'class']
