# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# DATA TYPE CONVERSION

# %%
data =pd.read_csv ('/content/data_clean.csv',index_col=0)

# %%
data.head()
# Out:
#    Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 1   41.0    190.0   7.4     67     5    1  2010    67       S
# 2   36.0    118.0   8.0     72     5    2  2010    72       C
# 3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 4   18.0    313.0  11.5     62     5    4  2010    62       S
# 5    NaN      NaN  14.3     56     5    5  2010    56       S

# %%
data
# Out:
#      Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 1     41.0    190.0   7.4     67     5    1  2010    67       S
# 2     36.0    118.0   8.0     72     5    2  2010    72       C
# 3     12.0    149.0  12.6     74     5    3  2010    74      PS
# 4     18.0    313.0  11.5     62     5    4  2010    62       S
# 5      NaN      NaN  14.3     56     5    5  2010    56       S
# ..     ...      ...   ...    ...   ...  ...   ...   ...     ...
# 154   41.0    190.0   7.4     67     5    1  2010    67       C
# 155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 156    NaN    145.0  13.2     77     9   27  2010    77       S
# 157   14.0    191.0  14.3     75     9   28  2010    75       S
# 158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(data.shape)
# Out:
# (158, 9)

# %%
data.dtypes
# Out:
# Ozone      float64
# Solar.R    float64
# Wind       float64
# Temp C      object
# Month       object
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %%
data.describe()
# Out:
#             Ozone     Solar.R        Wind         Day    Year        Temp
# count  120.000000  151.000000  158.000000  158.000000   158.0  158.000000
# mean    41.583333  185.403974    9.957595   16.006329  2010.0   77.727848
# std     32.620709   88.723103    3.511261    8.997166     0.0    9.377877
# min      1.000000    7.000000    1.700000    1.000000  2010.0   56.000000
# 25%     18.000000  119.000000    7.400000    8.000000  2010.0   72.000000
# 50%     30.500000  197.000000    9.700000   16.000000  2010.0   78.500000
# 75%     61.500000  257.000000   11.875000   24.000000  2010.0   84.000000
# max    168.000000  334.000000   20.700000   31.000000  2010.0   97.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 158 entries, 1 to 158
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Temp C   158 non-null    object
#  4   Month    158 non-null    object
#  5   Day      158 non-null    int64
#  6   Year     158 non-null    int64
#  7   Temp     158 non-null    int64
#  8   Weather  155 non-null    object
# dtypes: float64(3), int64(3), object(3)
# memory usage: 12.3+ KB

# %% [markdown]
# DATA TYPE CONVERSION

# %%
data['Month']=pd.to_numeric(data['Month'],errors='coerce')
data['Temp C']=pd.to_numeric(data['Temp C'],errors='coerce')
data['Weather']=data['Weather'].astype('category')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 158 entries, 1 to 158
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Temp C   157 non-null    float64
#  4   Month    157 non-null    float64
#  5   Day      158 non-null    int64
#  6   Year     158 non-null    int64
#  7   Temp     158 non-null    int64
#  8   Weather  155 non-null    category
# dtypes: category(1), float64(5), int64(3)
# memory usage: 11.4 KB

# %% [markdown]
# DUPLICATES

# %%
data.duplicated() #if any 2 rows has same values
# Out:
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 154    False
# 155    False
# 156    False
# 157     True
# 158    False
# Length: 158, dtype: bool

# %%
#count of duplicated rows
data[data.duplicated ()].shape
# Out:
# (1, 9)

# %%
#print the duplicated rows , recored 151 and 157 are duplicate rows
data[data.duplicated()]
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 157   14.0    191.0  14.3    75.0    9.0   28  2010    75       S

# %%
data_cleaned1=data.drop_duplicates()

# %%
data_cleaned1
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 1     41.0    190.0   7.4    67.0    5.0    1  2010    67       S
# 2     36.0    118.0   8.0    72.0    5.0    2  2010    72       C
# 3     12.0    149.0  12.6    74.0    5.0    3  2010    74      PS
# 4     18.0    313.0  11.5    62.0    5.0    4  2010    62       S
# 5      NaN      NaN  14.3    56.0    5.0    5  2010    56       S
# ..     ...      ...   ...     ...    ...  ...   ...   ...     ...
# 153   20.0    223.0  11.5    68.0    9.0   30  2010    68       S
# 154   41.0    190.0   7.4    67.0    5.0    1  2010    67       C
# 155   30.0    193.0   6.9    70.0    9.0   26  2010    70      PS
# 156    NaN    145.0  13.2    77.0    9.0   27  2010    77       S
# 158   18.0    131.0   8.0    76.0    9.0   29  2010    76       C
#
# [157 rows x 9 columns]

# %%
data_cleaned2=data_cleaned1.drop('Temp C',axis =1)

# %%
data_cleaned2
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 1     41.0    190.0   7.4    5.0    1  2010    67       S
# 2     36.0    118.0   8.0    5.0    2  2010    72       C
# 3     12.0    149.0  12.6    5.0    3  2010    74      PS
# 4     18.0    313.0  11.5    5.0    4  2010    62       S
# 5      NaN      NaN  14.3    5.0    5  2010    56       S
# ..     ...      ...   ...    ...  ...   ...   ...     ...
# 153   20.0    223.0  11.5    9.0   30  2010    68       S
# 154   41.0    190.0   7.4    5.0    1  2010    67       C
# 155   30.0    193.0   6.9    9.0   26  2010    70      PS
# 156    NaN    145.0  13.2    9.0   27  2010    77       S
# 158   18.0    131.0   8.0    9.0   29  2010    76       C
#
# [157 rows x 8 columns]

# %%
#rename the solar column , pass parameter in dictionry from
data_cleaned3=data_cleaned2.rename({'Soloar.R':'Solar'},axis=1)

# %%
data_clened3

# %%
#box plot 
data_box=data_cleaned3.dropna()
data1_box=data_box.Ozone
plt.boxplot(data1_box)
plt.show()

# %%
#extracting outliers
box=plt.boxplot(data1_box)

# %%
box
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f2cf4be6880>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f2cf4be6f40>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f2cf4be6520>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f2cf4bf0640>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f2cf4bf0940>],
#  'means': []}

# %%
[item.get_ydata()for item in box['fliers']]
# Out:
# [array([135., 168.])]

# %%
#Extracting outliers
box=plt.boxplot(data['Ozone'].dropna ())

# %%
data_cleaned3['Ozone'].describe()
# Out:
# count    119.000000
# mean      41.815126
# std       32.659249
# min        1.000000
# 25%       18.000000
# 50%       31.000000
# 75%       62.000000
# max      168.000000
# Name: Ozone, dtype: float64

# %%
#bar plot - to indentify outliers in categorical data -get count of unique vaules
data ['Weather'].value-counts().polt.bar()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-3efdf8cb707c> in <module>
#       1 #bar plot - to indentify outliers in categorical data -get count of unique vaules
# ----> 2 data ['Weather'].value-counts().polt.bar()
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'value'

# %% [markdown]
# Missing vaule imputation

# %%
import seaborn as sns#in seaborn documenttation color are mentioned
cols=data_cleaned3.columns#save column nnames in cols dataset
# colour = pink ,yellow # specify the colours - yellow is missing pink is not missing
colours=['pink','white']
sns.heatmap(data_cleaned3[cols].isnull(),
            cmap=sns.color_palette(colours))

# %% [markdown]
# sactter plot correlation

# %%
sns.pairplot(data_cleaned3)

# %%
#correlation
data_cleaned3.corr()
# Out:
#             Ozone   Solar.R      Wind     Month       Day  Year      Temp
# Ozone    1.000000  0.350274 -0.590270  0.147231 -0.025465   NaN  0.694404
# Solar.R  0.350274  1.000000 -0.057407 -0.094012 -0.155663   NaN  0.273558
# Wind    -0.590270 -0.057407  1.000000 -0.166216  0.029900   NaN -0.441228
# Month    0.147231 -0.094012 -0.166216  1.000000  0.050055   NaN  0.398516
# Day     -0.025465 -0.155663  0.029900  0.050055  1.000000   NaN -0.122787
# Year          NaN       NaN       NaN       NaN       NaN   NaN       NaN
# Temp     0.694404  0.273558 -0.441228  0.398516 -0.122787   NaN  1.000000

# %% [markdown]
# dummy variables

# %%
data
